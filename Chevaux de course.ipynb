# %% [markdown]
# Chevaux de course
# https://www.codingame.com/training/easy/horse-racing-duals
# by Bearzly

# %%
import sys
import math

# Auto-generated code below aims at helping you parse
# the standard input according to the problem statement.

n = int(input()) #n horses
pi = []
for i in range(n): #get list of value
    pi.append(int(input()))

pi.sort(reverse=True) #sort biggest to lowest
res = []
idx = 0
while idx < n-1 :
    res.append(pi[idx] - pi[idx+1]) #new list contains difference between n and n+1
    idx += 1

print(min(res)) #return lowest value
